# %%
import pandas as pd
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv('insurance.csv')

# %%
df.shape
# Out:
# (1338, 9)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'steps', 'children', 'smoker', 'region', 'charges',
#        'insuranceclaim'],
#       dtype='object')

# %%
df.head()
# Out:
#    age  sex     bmi  steps  children  smoker  region      charges
# 0   19    0  27.900   3009         0       1       3  16884.92400  \
# 1   18    1  33.770   3008         1       0       2   1725.55230
# 2   28    1  33.000   3009         3       0       2   4449.46200
# 3   33    1  22.705  10009         0       0       1  21984.47061
# 4   32    1  28.880   8010         0       0       1   3866.85520
#
#    insuranceclaim
# 0               1
# 1               1
# 2               0
# 3               0
# 4               1

# %%
# checking if null values exist in the dataset
df[df.isnull().any(axis=1)].head()
# Out:
# Empty DataFrame
# Columns: [age, sex, bmi, steps, children, smoker, region, charges, insuranceclaim]
# Index: []

# %%
# Split the train data in test and train
X = df.drop('insuranceclaim', axis=1)
y = df['insuranceclaim']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=324)

# %%
#fitting decision tree model on the data
insurance_classifier = DecisionTreeClassifier(max_leaf_nodes=10, random_state=0)
insurance_classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_leaf_nodes=10, random_state=0)

# %%
y_predicted = insurance_classifier.predict(X_test)

# %%
#checking test accuracy
accuracy_score(y_test,y_predicted)*100
# Out:
# 89.92537313432835

# %%
confusion_matrix(y_test, y_predicted)
# Out:
# array([[ 98,   6],
#        [ 21, 143]], dtype=int64)
